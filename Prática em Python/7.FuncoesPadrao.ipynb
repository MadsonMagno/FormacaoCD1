# %% [markdown]
# # Formação Cientista de Dados
# Funções Padrão

# %%
#funções internas
print(abs(-200))
lst = [1,2,30,30,45]
print("Maior valor: ", max(lst))
print("Menor valor: ", min(lst))
print("Soma: ", sum(lst))
print("Arredondamento: ", round(2.34567,2))
# Out:
# 200
# Maior valor:  45
# Menor valor:  1
# Soma:  108
# Arredondamento:  2.35

# %%
#statistica
from statistics import *
print("Média: ", mean(lst))
print("Mediana: ", median(lst))
print("Moda: ", mode(lst))
# Out:
# Média:  21.6
# Mediana:  30
# Moda:  30

# %%
#desvio padrão da amostra
print("Desvio padrão: ", stdev(lst))
# Out:
# Desvio padrão:  19.346834366376324

# %%
#variancia da amostra
print("Variância: ", variance(lst))
# Out:
# Variância:  374.3

# %%
from numpy import *
a = random.random((8,8))
print(type(a))
print(a)
# Out:
# <class 'numpy.ndarray'>
# [[0.46884058 0.26841341 0.99093949 0.35064642 0.5166508  0.37033846
#   0.29507621 0.15199763]
#  [0.7157058  0.53881872 0.96496315 0.69363351 0.87122311 0.36512233
#   0.51591071 0.0380205 ]
#  [0.61599719 0.36980205 0.50518902 0.65749154 0.50366909 0.88414149
#   0.22618458 0.56729347]
#  [0.21642582 0.77091727 0.78471933 0.74817059 0.42936083 0.98011938
#   0.5998029  0.14554446]
#  [0.71564769 0.96698251 0.94005251 0.64150929 0.49715917 0.36433407
#   0.55427461 0.90161705]
#  [0.06645608 0.76802933 0.7742771  0.78427974 0.80096546 0.08834861
#   0.44221113 0.92595972]
#  [0.333206   0.26023219 0.74074674 0.72017032 0.19334276 0.72593607
#   0.22389987 0.94208795]
#  [0.86144083 0.93322656 0.108135   0.39691617 0.83195455 0.36660437
#   0.89030677 0.28445448]]
